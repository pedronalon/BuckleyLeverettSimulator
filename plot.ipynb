# %%
import matplotlib.pyplot as plt
from simulator import So_history, Sw_history, x, plot_values

# %%
n = len(Sw_history)
for i in range(n):
    plt.figure(figsize=(12,8))
    plt.plot(x,Sw_history[i], label = 'Water Saturation')
    plt.plot(x,So_history[i], label = 'Oil Saturation')
    plt.title('t = {}'.format(plot_values[i]))
    plt.grid(True)
    plt.legend()   
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 6
#       4 plt.plot(x,Sw_history[i], label = 'Water Saturation')
#       5 plt.plot(x,So_history[i], label = 'Oil Saturation')
# ----> 6 plt.title('t = {}'.format(plot_values[i]))
#       7 plt.grid(True)
#       8 plt.legend()
#
# IndexError: list index out of range
